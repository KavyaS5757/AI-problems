# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dummy-photo/Aravam 23 (173 of 187).jpg

# %%
pip install instabot
# Out:
# ...
# ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
import instabot
from instabot import Bot

# %%
bot = Bot()
bot.login(username="kavyasubramanian2004", password="####")
bot.follow('thecriminalzcrew')
# Out:
# 2023-10-16 10:33:34,761 - INFO - Instabot version: 0.117.0 Started
# 2023-10-16 10:33:34,761 - INFO - Instabot version: 0.117.0 Started
# 2023-10-16 10:33:34,761 - INFO - Instabot version: 0.117.0 Started
# 2023-10-16 10:33:34,761 - INFO - Instabot version: 0.117.0 Started
# 2023-10-16 10:33:34,761 - INFO - Instabot version: 0.117.0 Started
# 2023-10-16 10:33:34,761 - INFO - Instabot version: 0.117.0 Started
# 2023-10-16 10:33:34,769 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2023-10-16 10:33:34,769 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2023-10-16 10:33:34,769 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2023-10-16 10:33:34,769 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2023-10-16 10:33:34,769 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2023-10-16 10:33:34,769 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2023-10-16 10:33:36,880 - ERROR - Request returns 400 error!
# ...

# %%
#bot.upload_photo("kaggle/input/dummy-photo",caption="When the force reunites")

# %%
bot.unfollow("iitbombay_ecell")

# %%
bot.send_message("I miss you a lot",["Our family"])

# %%
followers=bot.get_user_followers("kavyasubramanian2004")
for follower in followers:
    print(bot.get_user_info(follower))
# Out:
# 2023-10-16 10:33:10,425 - CRITICAL - Not logged in!
# 2023-10-16 10:33:10,425 - CRITICAL - Not logged in!
# 2023-10-16 10:33:10,425 - CRITICAL - Not logged in!
# 2023-10-16 10:33:10,425 - CRITICAL - Not logged in!
# 2023-10-16 10:33:10,425 - CRITICAL - Not logged in!
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 followers=bot.get_user_followers("kavyasubramanian2004")
#
# File /opt/conda/lib/python3.10/site-packages/instabot/bot/bot.py:615, in Bot.get_user_followers(self, user_id, nfollows)
#     614 def get_user_followers(self, user_id, nfollows=None):
# --> 615     return get_user_followers(self, user_id, nfollows)
#
# File /opt/conda/lib/python3.10/site-packages/instabot/bot/bot_get.py:236, in get_user_followers(self, user_id, nfollows)
#     235 def get_user_followers(self, user_id, nfollows):
# ...

# %%
following = bot.get_user_following("kavyasubramanian2004")
for Following in following:
    print(bot.get_user_info(Following))
